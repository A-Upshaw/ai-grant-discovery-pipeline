# %% [markdown]
# # Maryland Funding Opportunities Pipeline - v2

# %% [markdown]
# **Capstone Project:** INFO 588 - AI-Driven Data Ingestion Pipeline
# **Rebuilt using:** INFO 570 (Data Wrangling) techniques + Azure AI extraction

# %%
# The full pipeline code is available at:
# /Users/Jarvis/.openclaw/workspace/the_vault/school/INFO 588 - Capstone/scrapers/Maryland/maryland_pipeline_v2.py

# Run this cell to execute the pipeline in notebook mode
# %run -i maryland_pipeline_v2.py
